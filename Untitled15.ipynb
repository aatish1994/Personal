# %%
#Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#uploading dataset
data=pd.read_csv('dataset.csv')
data
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#Checking shape
data.shape
# Out:
# (43400, 12)

# %% [markdown]
# **So we can see that there are about 43400 rows and 12 columns present in the dataset.**

# %%
#Checking type of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.0+ MB

# %% [markdown]
# **So we can see that 4 columns have integer type of data, 3 columns have float type of data and 5 columns have string or object type of data.**

# %%
#Checking for null values
data.isna().sum()
# Out:
# id                       0
# gender                   0
# age                      0
# hypertension             0
# heart_disease            0
# ever_married             0
# work_type                0
# Residence_type           0
# avg_glucose_level        0
# bmi                   1462
# smoking_status       13292
# stroke                   0
# dtype: int64

# %% [markdown]
# **We can see that two columns have null values. In column bmi 1462 and in column smoking status 13292 null values are present.**

# %%
data.describe()
# Out:
#                  id           age  hypertension  heart_disease  \
# count  43400.000000  43400.000000  43400.000000   43400.000000
# mean   36326.142350     42.217894      0.093571       0.047512
# std    21072.134879     22.519649      0.291235       0.212733
# min        1.000000      0.080000      0.000000       0.000000
# 25%    18038.500000     24.000000      0.000000       0.000000
# 50%    36351.500000     44.000000      0.000000       0.000000
# 75%    54514.250000     60.000000      0.000000       0.000000
# max    72943.000000     82.000000      1.000000       1.000000
#
#        avg_glucose_level           bmi        stroke
# count       43400.000000  41938.000000  43400.000000
# mean          104.482750     28.605038      0.018041
# std            43.111751      7.770020      0.133103
# min            55.000000     10.100000      0.000000
# 25%            77.540000     23.200000      0.000000
# 50%            91.580000     27.700000      0.000000
# ...

# %% [markdown]
# **By looking at the dataset, it looks like in all the columns there is a normal distribution and also outliers wont be present. But will reconfirm by plotting dist plot and box plot.**

# %%
#Checking for name of the columns
data.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %% [markdown]
# **CHECKING FOR UNIQUE VALUES**

# %%
#Checking unique values of column gender
data['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %% [markdown]
# **In column gender 3 unique values are present i.e male and female.**

# %%
#Checking unique values of column hypertension
data['hypertension'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# **In column hypertension 2 unique values are present i.e 0 means does not have hypertesnion and 1 means who have hypertension**

# %%
#Checking unique values of column heart disease
data['heart_disease'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# **In column heart_disease 2 unique values are present i.e 0 means who does not have heart disease and 1 means who have heart disease.**

# %%
#Checking unique values of column ever married
data['ever_married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# **In column ever_married 2 unique values are present i.e No means who is not married and yes means who is married.**

# %%
#Checking unique values of column Residence type
data['Residence_type'].unique()
# Out:
# array(['Rural', 'Urban'], dtype=object)

# %% [markdown]
# **In column Residence_type 2 unique values are present i.e rural means people living in rural area and urban means people living in urban area.**

# %%
#Checking unique values of column smoking status
data['smoking_status'].unique()
# Out:
# array([nan, 'never smoked', 'formerly smoked', 'smokes'], dtype=object)

# %% [markdown]
# **In column smoking_status 3 unique values are present i.e never smoked means the people who have never smoked , formely smoked means the people who had smoked earlier only on some occassions and now they have stopped smoking and smokes means the poeple who are currently smoking.**

# %%
#Checking unique values of column work type
data['work_type'].unique()
# Out:
# array(['children', 'Private', 'Never_worked', 'Self-employed', 'Govt_job'],
#       dtype=object)

# %% [markdown]
# **In column work_type 5 unique values are present i.e children means the people who are teens, private means the people who are working in private sector, never worked means the people who have never worked, self employed means the people who are self employed like doing business and all and government job means the people who are working in government sector.**

# %%
#Checking unique values of column stroke
data['stroke'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# **In column stroke 2 unique values are present i.e 0 means the people who have not got stroke and 1 means the people who have got stroke.**

# %%
#Checking number of unique values of column id
data['id'].nunique()
# Out:
# 43400

# %% [markdown]
# **In column id 43400 unique values are present.**

# %%
#Checking number of unique values of column age
data['age'].nunique()
# Out:
# 104

# %% [markdown]
# **In column age 104 unique values are present.**

# %%
#Checking number of unique values of column avg glucose level
data['avg_glucose_level'].nunique()
# Out:
# 12543

# %% [markdown]
# **In column avg_glucose_level 12453 unique values are present.**

# %%
#Checking number of unique values of column bmi
data['bmi'].nunique()
# Out:
# 555

# %% [markdown]
# **In column bmi 555 unique values are present.**

# %% [markdown]
# **Checking for value counts**

# %%
#Checking for value counts
data['gender'].value_counts()
# Out:
# Female    25665
# Male      17724
# Other        11
# Name: gender, dtype: int64

# %% [markdown]
# **So we can see that around 25665 female, 17724 male and 11 others are there in the dataset.**

# %%
#Checking for value counts
data['hypertension'].value_counts()
# Out:
# 0    39339
# 1     4061
# Name: hypertension, dtype: int64

# %% [markdown]
# **So we can see that 39339 people does not have hypertension and 4061 people have hypertension.**

# %%
#Checking for value counts
data['heart_disease'].value_counts()
# Out:
# 0    41338
# 1     2062
# Name: heart_disease, dtype: int64

# %% [markdown]
# **So we can see that 41338 people does not have heart disease and 2062 have heart disease.**

# %%
#Checking for value counts
data['ever_married'].value_counts()
# Out:
# Yes    27938
# No     15462
# Name: ever_married, dtype: int64

# %% [markdown]
# **So we can see that around 27938 people are married and 15462 have not married.**

# %%
#Checking for value counts
data['work_type'].value_counts()
# Out:
# Private          24834
# Self-employed     6793
# children          6156
# Govt_job          5440
# Never_worked       177
# Name: work_type, dtype: int64

# %% [markdown]
# **So we can see that around 24834 people are working in private sector, 6793 are self employed, 6156 are childrens, 5440 are working in government sectors and 177 have never worked.**

# %%
#Checking for value counts
data['Residence_type'].value_counts()
# Out:
# Urban    21756
# Rural    21644
# Name: Residence_type, dtype: int64

# %% [markdown]
# **So we can see that around 21756 people lives in urban area and 21644 lives in rural area.**

# %%
#Checking for value counts
data['smoking_status'].value_counts()
# Out:
# never smoked       16053
# formerly smoked     7493
# smokes              6562
# Name: smoking_status, dtype: int64

# %% [markdown]
# **So we can see that around 16053 people have never smoked, 7493 have formely smoked and 6562 are smoking.**

# %%
#Checking for value counts
data['stroke'].value_counts()
# Out:
# 0    42617
# 1      783
# Name: stroke, dtype: int64

# %% [markdown]
# **So we can see that around 42617 people have not got stroke and 783 have got stroke.**

# %%
#plotting count plots
sns.countplot(x='gender',data=data)
plt.show()

# %%
#plotting count plots
sns.countplot(x='hypertension',data=data)
plt.show()

# %%
#plotting count plots
sns.countplot(x='heart_disease',data=data)
plt.show()

# %%
#plotting count plots
sns.countplot(x='ever_married',data=data)
plt.show()

# %%
#plotting count plots
plt.figure(figsize=(10,5))
sns.countplot(x='work_type',data=data)
plt.show()

# %%
#plotting count plots
sns.countplot(x='Residence_type',data=data)
plt.show()

# %%
#plotting count plots
sns.countplot(x='smoking_status',data=data)
plt.show()

# %%
#plotting dist plot
sns.distplot(data['age'])
plt.show()

# %%
#plotting dist plot
sns.distplot(data['avg_glucose_level'])
plt.show()

# %%
#plotting dist plot
sns.distplot(data['bmi'])
plt.show()

# %%
#Filtering the data where people never got stroke
stroke_no=data[data['stroke']==0]
stroke_no
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#plotting count plot
sns.countplot(x='gender',data=stroke_no)
plt.show()

# %%
#plotting count plot
sns.countplot(x='smoking_status',data=stroke_no)
plt.show()

# %%
#plotting count plot
sns.countplot(x='heart_disease',data=stroke_no)
plt.show()

# %%
#plotting count plot
sns.countplot(x='hypertension',data=stroke_no)
plt.show()

# %%
#plotting count plot
sns.countplot(x='ever_married',data=stroke_no)
plt.show()

# %%
#Filtering the data where people got stroke
stroke_yes=data[data['stroke']==1]
stroke_yes
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 63      9046    Male  67.0             0              1          Yes
# 81     51676  Female  61.0             0              0          Yes
# 141    31112    Male  80.0             0              1          Yes
# 257    60182  Female  49.0             0              0          Yes
# 264     1665  Female  79.0             1              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 43148  25110  Female  56.0             0              0          Yes
# 43268   5392    Male  69.0             0              0          Yes
# 43304  35057  Female  80.0             0              0          Yes
# 43318  64109    Male  62.0             1              1          Yes
# 43339  10463  Female  76.0             0              0           No
#
#            work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#plotting count plot
sns.countplot(x='gender',data=stroke_yes)
plt.show()

# %%
#plotting count plot
sns.countplot(x='hypertension',data=stroke_yes)
plt.show()

# %%
#plotting count plot
sns.countplot(x='heart_disease',data=stroke_yes)
plt.show()

# %%
#plotting count plot
sns.countplot(x='ever_married',data=stroke_yes)
plt.show()

# %%
#plotting count plot
sns.countplot(x='smoking_status',data=stroke_yes)
plt.show()

# %%
#Filtering data were age is below 20
age_below_20=data[data['age']<=20.0]
age_below_20
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 2      16523  Female   8.0             0              0           No
# 4      46136    Male  14.0             0              0           No
# 16     19584  Female  20.0             0              0           No
# 33     33759  Female   3.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43387  25888    Male  20.0             0              0           No
# 43389  30759    Male  14.0             0              0           No
# 43391  30077    Male   6.0             0              0           No
# 43392  45266  Female  18.0             0              0           No
# 43395  56196  Female  10.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# ...

# %%
#checking value counts of stroke
age_below_20['stroke'].value_counts()
# Out:
# 0    9013
# 1       2
# Name: stroke, dtype: int64

# %%
#Plotting count plot
sns.countplot(x='gender',data=age_below_20)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='hypertension',data=age_below_20)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='heart_disease',data=age_below_20)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='smoking_status',data=age_below_20)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='stroke',data=age_below_20)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='ever_married',data=age_below_20)
plt.show()

# %%
#checking for the data of the person who got stroke
age_below_20.loc[age_below_20['stroke']==1]
# Out:
#           id  gender    age  hypertension  heart_disease ever_married  \
# 9961   69768  Female   1.32             0              0           No
# 14802  49669  Female  14.00             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 9961   children          Urban              70.37   NaN            NaN       1
# 14802  children          Rural              57.93  30.9            NaN       1

# %%
#checking for the data of the person who smokes
age_below_20.loc[age_below_20['smoking_status']=='smokes']
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 16     19584  Female  20.0             0              0           No
# 82     54918  Female  18.0             0              0           No
# 523    40055  Female  17.0             0              0           No
# 620    16110  Female  19.0             0              0           No
# 716    30605  Female  20.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 42253  63644  Female  20.0             0              0           No
# 42315  13903    Male  18.0             0              0           No
# 42481  68938  Female  17.0             0              0           No
# 42898  14191  Female  17.0             0              0           No
# 43295  20215  Female  18.0             0              0           No
#
#            work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# ...

# %%
#checking for the data of the person who formely smoked
age_below_20.loc[age_below_20['smoking_status']=='formerly smoked']
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 579     7663    Male  20.0             0              0           No
# 890    69224    Male  19.0             0              0           No
# 1160   68235    Male  12.0             0              0           No
# 1462   37698  Female  15.0             0              0           No
# 1551   57109  Female  12.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 42193  25194    Male  12.0             0              0           No
# 42215  36615  Female  16.0             0              0           No
# 42575   2136  Female  15.0             0              0           No
# 42726  62875  Female  15.0             0              0           No
# 42923  63594  Female  17.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#checking for value counts
age_below_20['stroke'].value_counts()
# Out:
# 0    9013
# 1       2
# Name: stroke, dtype: int64

# %%
#Filtering the data where age is between 20 to 30
age_20_30=data[(data['age'] > 20.0) & (data['age'] <= 30)]
age_20_30
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 25     70336  Female  25.0             0              0          Yes
# 30     67210    Male  27.0             0              0          Yes
# 37     36811  Female  23.0             0              0           No
# 45     34974  Female  22.0             0              0           No
# 55     41648    Male  27.0             0              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 43328  37620  Female  23.0             0              0           No
# 43334  55014    Male  30.0             0              0          Yes
# 43360  32413    Male  25.0             0              0           No
# 43378  12555    Male  22.0             0              0           No
# 43380  46293    Male  26.0             0              0          Yes
#
#            work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#Plotting count plot
sns.countplot(x='gender',data=age_20_30)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='hypertension',data=age_20_30)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='heart_disease',data=age_20_30)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='smoking_status',data=age_20_30)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='ever_married',data=age_20_30)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='stroke',data=age_20_30)
plt.show()

# %%
#checking for value counts
age_20_30['stroke'].value_counts()
# Out:
# 0    5219
# 1       2
# Name: stroke, dtype: int64

# %%
#Filtering the data where age is between 30 to 60
age_30_60=data[(data['age']>30.0) & (data['age']<=60)]
age_30_60
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 1      30468    Male  58.0             1              0          Yes
# 5      32257  Female  47.0             0              0          Yes
# 6      52800  Female  52.0             0              0          Yes
# 8      15266  Female  32.0             0              0          Yes
# 12     63884  Female  37.0             0              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 43381  57176    Male  45.0             0              0          Yes
# 43393  69344    Male  39.0             0              0          Yes
# 43394  52380    Male  47.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#Plotting count plot
sns.countplot(x='gender',data=age_30_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='hypertension',data=age_30_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='heart_disease',data=age_30_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='smoking_status',data=age_30_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='ever_married',data=age_30_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='stroke',data=age_30_60)
plt.show()

# %%
#checking for value counts
age_30_60['stroke'].value_counts()
# Out:
# 0    18453
# 1      200
# Name: stroke, dtype: int64

# %%
#Filtering the data where age is greater than 60
age_greater_60=data[(data['age']>60)]
age_greater_60
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 3      56543  Female  70.0             0              0          Yes
# 7      41413  Female  75.0             0              1          Yes
# 9      28674  Female  74.0             1              0          Yes
# 10     10460  Female  79.0             0              0          Yes
# 11     64908    Male  79.0             0              1          Yes
# ...      ...     ...   ...           ...            ...          ...
# 43386  18828    Male  68.0             0              1          Yes
# 43388  31321  Female  64.0             1              0          Yes
# 43390  10096  Female  69.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#            work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#Plotting count plot
sns.countplot(x='gender',data=age_greater_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='hypertension',data=age_greater_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='heart_disease',data=age_greater_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='smoking_status',data=age_greater_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='ever_married',data=age_greater_60)
plt.show()

# %%
#Plotting count plot
sns.countplot(x='stroke',data=age_greater_60)
plt.show()

# %%
#checking for value counts
age_greater_60['stroke'].value_counts()
# Out:
# 0    9932
# 1     579
# Name: stroke, dtype: int64

# %%
#Filtering out the data where people smokes
smokes=data[(data['smoking_status'] =='smokes')]
smokes
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 8      15266  Female  32.0             0              0          Yes
# 16     19584  Female  20.0             0              0           No
# 18     49589  Female  44.0             0              0          Yes
# 19     17986  Female  79.0             0              1          Yes
# 21     72911  Female  57.0             1              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 43359  71215  Female  59.0             0              0          Yes
# 43364  18920    Male  56.0             0              0          Yes
# 43373   2712  Female  46.0             0              0           No
# 43374  35172    Male  49.0             0              0          Yes
# 43388  31321  Female  64.0             1              0          Yes
#
#            work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# ...

# %%
#plotting count plot
sns.countplot(x='gender',data=smokes)
plt.show()

# %%
#plotting count plot
sns.countplot(x='stroke',data=smokes)
plt.show()

# %%
#Filtering out the data where people formely smoked
formely_smoked=data[(data['smoking_status'] =='formerly smoked')]
formely_smoked
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 3      56543  Female  70.0             0              0          Yes
# 6      52800  Female  52.0             0              0          Yes
# 11     64908    Male  79.0             0              1          Yes
# 13     37893  Female  37.0             0              0          Yes
# 23      4057    Male  71.0             0              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 43381  57176    Male  45.0             0              0          Yes
# 43384  44814  Female  65.0             0              0          Yes
# 43394  52380    Male  47.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#plotting count plot
sns.countplot(x='gender',data=formely_smoked)
plt.show()

# %%
#plotting count plot
sns.countplot(x='stroke',data=formely_smoked)
plt.show()

# %%
#Filtering out the data where people never smoked
never_smoked=data[(data['smoking_status'] =='never smoked')]
never_smoked
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 1      30468    Male  58.0             1              0          Yes
# 7      41413  Female  75.0             0              1          Yes
# 9      28674  Female  74.0             1              0          Yes
# 12     63884  Female  37.0             0              0          Yes
# 14     67855  Female  40.0             0              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 43390  10096  Female  69.0             0              0          Yes
# 43393  69344    Male  39.0             0              0          Yes
# 43395  56196  Female  10.0             0              0           No
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#            work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# ...

# %%
#plotting count plot
sns.countplot(x='gender',data=never_smoked)
plt.show()

# %%
#plotting count plot
sns.countplot(x='stroke',data=never_smoked)
plt.show()

# %%
#Filtering out the data of people who have hypertension, heart disease and who smokes
hype_heal_smo=data[(data['hypertension'] == 1) & (data['heart_disease'] ==1) & (data['smoking_status']=='smokes')]
hype_heal_smo
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 654    72310    Male  80.0             1              1          Yes
# 1529   29179  Female  76.0             1              1          Yes
# 1641   16066  Female  53.0             1              1          Yes
# 2220   22136    Male  78.0             1              1           No
# 2499   35069  Female  50.0             1              1           No
# ...      ...     ...   ...           ...            ...          ...
# 41547  62684    Male  77.0             1              1          Yes
# 41557  50961    Male  42.0             1              1          Yes
# 42035  40178    Male  53.0             1              1          Yes
# 42231  62190    Male  62.0             1              1          Yes
# 42889  31002    Male  69.0             1              1          Yes
#
#            work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# ...

# %%
#plotting count plot
sns.countplot(x='stroke',data=hype_heal_smo)
plt.show()

# %%
#plotting count plot
sns.countplot(x='gender',data=hype_heal_smo)
plt.show()

# %%
#Filetring out the data where people does not have hypertension,heart disease and who does not smoke
no_hype_no_heal_no_smo=data[(data['hypertension']==0)& (data['heart_disease']==0)& (data['smoking_status']=='never smoked')]
no_hype_no_heal_no_smo
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 12     63884  Female  37.0             0              0          Yes
# 14     67855  Female  40.0             0              0          Yes
# 15     25774    Male  35.0             0              0           No
# 17     24447  Female  42.0             0              0          Yes
# 24     48588  Female  59.0             0              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 43390  10096  Female  69.0             0              0          Yes
# 43393  69344    Male  39.0             0              0          Yes
# 43395  56196  Female  10.0             0              0           No
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#            work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# ...

# %%
#plotting count plot
sns.countplot(x='stroke',data=no_hype_no_heal_no_smo)
plt.show()

# %%
#plotting count plot
sns.countplot(x='gender',data=no_hype_no_heal_no_smo)
plt.show()

# %%
#Filtering out the data for male
male=data[data['gender']=='Male']

# %%
#filetring out the data for female
female=data[data['gender']=='Female']

# %%
#plotting countplot
sns.countplot(x='stroke',data=male)
plt.show()

# %%
#checking value counts
male['stroke'].value_counts()
# Out:
# 0    17372
# 1      352
# Name: stroke, dtype: int64

# %%
#plotting countplot
sns.countplot(x='stroke',data=female)
plt.show()

# %%
#checking value counts
female['stroke'].value_counts()
# Out:
# 0    25234
# 1      431
# Name: stroke, dtype: int64

# %%
#plotting countplot
sns.countplot(x='hypertension',data=male)
plt.show()

# %%
#plotting countplot
sns.countplot(x='heart_disease',data=male)
plt.show()

# %%
#plotting countplot
sns.countplot(x='hypertension',data=female)
plt.show()

# %%
#plotting countplot
sns.countplot(x='heart_disease',data=female)
plt.show()

# %%
#filling the null values using mode
data['smoking_status']=data['smoking_status'].fillna(data['smoking_status'].mode()[0])

# %%
#Filling the null values using median as their are outliers present in this column
data['bmi']=data['bmi'].fillna(data['bmi'].median())

# %%
#checking for null values
data.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
#checking value counts 
data['stroke'].value_counts()
# Out:
# 0    42617
# 1      783
# Name: stroke, dtype: int64

# %%
#Importing required libraries
from sklearn.preprocessing import LabelEncoder

# %%
#Encoding
lab_enc=LabelEncoder()
df1=lab_enc.fit_transform(data['gender'])
df2=lab_enc.fit_transform(data['ever_married'])
df3=lab_enc.fit_transform(data['work_type'])
df4=lab_enc.fit_transform(data['Residence_type'])
df5=lab_enc.fit_transform(data['smoking_status'])

# %%
#Transfering the data 
data['gender']=df1
data['ever_married']=df2
data['work_type']=df3
data['Residence_type']=df4
data['smoking_status']=df5

# %%
#Checking whether the data is encoded or not
data.head(1)
# Out:
#       id  gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0  30669       1  3.0             0              0             0          4
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               0              95.12  18.0               1       0

# %%
#Checking for correlation
data.drop(['stroke'],axis=1).corrwith(data['stroke']).plot(kind='bar',grid=True,figsize=(20,10),title='Correlation with stroke')
plt.show()

# %%
#dropping columns id and resident type
data=data.drop(['id','Residence_type'],axis=1)
data.head(1)
# Out:
#    gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  3.0             0              0             0          4
#
#    avg_glucose_level   bmi  smoking_status  stroke
# 0              95.12  18.0               1       0

# %%
#Plotting heatmap
corr=data.corr().abs()
plt.figure(figsize=(25,15))
sns.heatmap(corr,annot=True)
plt.show()

# %%
#Checking skewness
data.skew()
# Out:
# gender               0.377020
# age                 -0.102497
# hypertension         2.791199
# heart_disease        4.254252
# ever_married        -0.600288
# work_type           -0.296065
# avg_glucose_level    1.675405
# bmi                  0.898728
# smoking_status       0.072386
# stroke               7.242226
# dtype: float64

# %%
#plotting dist plot
sns.distplot(data['avg_glucose_level'])
plt.show()

# %%
#plotting dist plot
sns.distplot(data['bmi'])
plt.show()

# %%
#Importing required libraries
from sklearn.preprocessing import power_transform

# %%
data[['avg_glucose_level','bmi']]=power_transform(data[['avg_glucose_level','bmi']],method='yeo-johnson')
data[['avg_glucose_level','bmi']]
# Out:
#        avg_glucose_level       bmi
# 0               0.102810 -1.625285
# 1              -0.161207  1.339892
# 2               0.559669 -1.709745
# 3              -1.135166  1.001936
# 4               1.401727 -1.401954
# ...                  ...       ...
# 43395          -1.950468 -1.153390
# 43396           1.842052  2.673470
# 43397          -0.009164  0.170946
# 43398           0.234294  0.701927
# 43399          -0.538181 -1.116506
#
# [43400 rows x 2 columns]

# %%
#Checking for skewness
data.skew()
# Out:
# gender               0.377020
# age                 -0.102497
# hypertension         2.791199
# heart_disease        4.254252
# ever_married        -0.600288
# work_type           -0.296065
# avg_glucose_level    0.068108
# bmi                 -0.000123
# smoking_status      -0.003427
# stroke               7.242226
# dtype: float64

# %%
#plotting dist plot
sns.distplot(data['bmi'])
plt.show()

# %%
#plotting dist plot
sns.distplot(data['avg_glucose_level'])
plt.show()

# %%
#plotting box plot to check outliers
data['age'].plot.box()
plt.show()

# %%
#plotting box plot to check outliers
data['bmi'].plot.box()
plt.show()

# %%
#plotting box plot to check outliers
data['avg_glucose_level'].plot.box()
plt.show()

# %%
#Importing required libraries
from scipy.stats import zscore

# %%
#Removing outliers
z_score=zscore(data[['bmi']])
abs_z_score=np.abs(z_score)
threshold=3
z=(abs_z_score<3).all(axis=1)

# %%
data.shape
# Out:
# (43400, 10)

# %%
data[z].shape
# Out:
# (43283, 10)

# %%
#Percentage Loss of Data
data_loss=((43400-43283)/18249)*100
print(f'Data Loss:{data_loss} %')
# Out:
# Data Loss:0.6411310208778563 %

# %%
data=data[z]

# %%
#Dividing dataset into features and label
#Features
x=data.drop(['stroke'],axis=1)
#Label
y=data['stroke']

# %%
#Standardiziing the data
#Importing require libraries
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
x_scaler=Scaler.fit_transform(x)
x_scaler
# Out:
# array([[ 1.20102955, -1.74261995, -0.32085557, ...,  0.10307051,
#         -1.64491026,  0.03797646],
#        [ 1.20102955,  0.69990916,  3.11666711, ..., -0.16108321,
#          1.36303572,  0.03797646],
#        [-0.83087172, -1.52057185, -0.32085557, ...,  0.56016839,
#         -1.7305881 ,  0.03797646],
#        ...,
#        [-0.83087172,  1.76574004,  3.11666711, ..., -0.00896192,
#          0.1772292 , -1.72002888],
#        [ 1.20102955, -0.09946401, -0.32085557, ...,  0.23462322,
#          0.71586912,  0.03797646],
#        [-0.83087172,  1.76574004, -0.32085557, ..., -0.53825386,
#         -1.12879302,  0.03797646]])

# %%
#Using oversampling method-Smote method
#importing required libraries
from imblearn.over_sampling import SMOTE

# %%
data['stroke'].value_counts()
# Out:
# 0    42500
# 1      783
# Name: stroke, dtype: int64

# %%
over_samp=SMOTE()

# %%
x_new,y_new=over_samp.fit_resample(x,y)

# %%
print('The number of classes before fit {}'.format(y.value_counts()))
# Out:
# The number of classes before fit 0    42500
# 1      783
# Name: stroke, dtype: int64

# %%
print('The number of classes after fit {}'.format(y_new.value_counts()))
# Out:
# The number of classes after fit 0    42500
# 1    42500
# Name: stroke, dtype: int64

# %%
#Importing required libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score,plot_roc_curve,f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
#Initiating Logistic Regression
lr=LogisticRegression()

# %%
#using range fucntion to find the best random state using Logestic regression
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    pred=lr.predict(x_train)
    y_pred=lr.predict(x_test)
    print(f'at random state{i},the training accuracy is:{accuracy_score(y_train,pred)*100}')
    print(f'at random state{i},the testing accuracy is:{accuracy_score(y_test,y_pred)*100}')
    print('\n')
# Out:
# at random state0,the training accuracy is:77.21725490196079
# at random state0,the testing accuracy is:77.42117647058824
#
#
# at random state1,the training accuracy is:77.37411764705882
# at random state1,the testing accuracy is:77.19058823529411
#
#
# at random state2,the training accuracy is:77.07137254901961
# at random state2,the testing accuracy is:77.86352941176472
#
#
# at random state3,the training accuracy is:77.3756862745098
# at random state3,the testing accuracy is:77.24705882352941
#
#
# at random state4,the training accuracy is:77.25019607843137
# at random state4,the testing accuracy is:77.44
#
#
# at random state5,the training accuracy is:77.34901960784313
# at random state5,the testing accuracy is:77.19058823529411
#
#
# at random state6,the training accuracy is:77.31294117647059
# at random state6,the testing accuracy is:77.27529411764706
#
#
# at random state7,the training accuracy is:77.33333333333333
# at random state7,the testing accuracy is:77.04470588235294
# ...

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=47)

# %%
def metric_score(clf, x_train, x_test, y_train, y_test, train=True):
    if train:
        pred = clf.predict(x_train)
        print('\n=====Train Score=====')
        print(f'Accuracy Score: {accuracy_score(y_train, pred) * 100:.2f}%')
    elif not train:
        y_pred = clf.predict(x_test)
        print('\n=====Test Score=====')
        print(f'Accuracy Score: {accuracy_score(y_test, y_pred) * 100:.2f}%')
        print('\n Test Classification Report:\n', classification_report(y_test, y_pred, digits=2))
        
        # Calculate the confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        TP, FP, FN, TN = conf_matrix.ravel()

        print('\n Confusion Matrix:\n', conf_matrix)
        print('\n True Negatives (TN):', TP)
        print(' False Positives (FP):', FP)
        print(' False Negatives (FN):', FN)
        print(' True Positives (TP):', TN)
        print('\n F1 Score:\n',f1_score(y_test,y_pred))
        sensitivity = TP / (TP + FN)
        print(f'Sensitivity (Recall): {sensitivity * 100:.2f}%')
        specificity = TN / (TN + FP)
        print(f'Specificity (True Negative Rate):{specificity*100:.2f}%')

# %%
#Training the data
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(lr,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(lr,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score: 77.31%
#
# =====Test Score=====
# Accuracy Score: 77.31%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77     10603
#            1       0.76      0.80      0.78     10647
#
#     accuracy                           0.77     21250
#    macro avg       0.77      0.77      0.77     21250
# weighted avg       0.77      0.77      0.77     21250
#
#
#  Confusion Matrix:
#  [[7905 2698]
#  [2124 8523]]
#
#  True Negatives (TN): 7905
#  False Positives (FP): 2698
#  False Negatives (FN): 2124
#  True Positives (TP): 8523
#
#  F1 Score:
#  0.7794951527345894
# Sensitivity (Recall): 78.82%
# Specificity (True Negative Rate):75.96%

# %%
#Checking Cross Validation score
#Importing required libraries
from sklearn.model_selection import cross_val_score

# %%
y_pred=lr.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(lr,x_new,y_new,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.773and accuracy for the testing is 0.7730823529411764
#
#
# at cross fold 3 the cv score is0.7727647501095877and accuracy for the testing is 0.7730823529411764
#
#
# at cross fold 4 the cv score is0.773435294117647and accuracy for the testing is 0.7730823529411764
#
#
# at cross fold 5 the cv score is0.7728588235294117and accuracy for the testing is 0.7730823529411764

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.         0.25445629 1.        ]
# TPR [0.         0.80050719 1.        ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
#Instantiating the models
rfc=RandomForestClassifier()

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=47)

# %%
#Training the data
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(rfc,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(rfc,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score: 100.00%
#
# =====Test Score=====
# Accuracy Score: 96.35%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96     10603
#            1       0.95      0.98      0.96     10647
#
#     accuracy                           0.96     21250
#    macro avg       0.96      0.96      0.96     21250
# weighted avg       0.96      0.96      0.96     21250
#
#
#  Confusion Matrix:
#  [[10014   589]
#  [  186 10461]]
#
#  True Negatives (TN): 10014
#  False Positives (FP): 589
#  False Negatives (FN): 186
#  True Positives (TP): 10461
#
#  F1 Score:
#  0.9642807761441674
# Sensitivity (Recall): 98.18%
# Specificity (True Negative Rate):94.67%

# %%
y_pred=rfc.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(rfc,x_new,y_new,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.9523882352941176and accuracy for the testing is 0.963764705882353
#
#
# at cross fold 3 the cv score is0.9606235876700756and accuracy for the testing is 0.963764705882353
#
#
# at cross fold 4 the cv score is0.963070588235294and accuracy for the testing is 0.963764705882353
#
#
# at cross fold 5 the cv score is0.9643882352941177and accuracy for the testing is 0.963764705882353

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.         0.05507875 1.        ]
# TPR [0.         0.98253029 1.        ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
#Instantiating the models
knn=KNeighborsClassifier()

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=47)

# %%
#Training the data
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(knn,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(knn,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score: 94.80%
#
# =====Test Score=====
# Accuracy Score: 92.69%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92     10603
#            1       0.88      0.99      0.93     10647
#
#     accuracy                           0.93     21250
#    macro avg       0.93      0.93      0.93     21250
# weighted avg       0.93      0.93      0.93     21250
#
#
#  Confusion Matrix:
#  [[ 9152  1451]
#  [  103 10544]]
#
#  True Negatives (TN): 9152
#  False Positives (FP): 1451
#  False Negatives (FN): 103
#  True Positives (TP): 10544
#
#  F1 Score:
#  0.931366487059447
# Sensitivity (Recall): 98.89%
# Specificity (True Negative Rate):87.90%

# %%
y_pred=knn.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(knn,x_new,y_new,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.9116588235294117and accuracy for the testing is 0.9268705882352941
#
#
# at cross fold 3 the cv score is0.9223294085598521and accuracy for the testing is 0.9268705882352941
#
#
# at cross fold 4 the cv score is0.9270117647058824and accuracy for the testing is 0.9268705882352941
#
#
# at cross fold 5 the cv score is0.9289411764705882and accuracy for the testing is 0.9268705882352941

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.         0.13684806 1.        ]
# TPR [0.         0.99032591 1.        ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
#Instantiating the models
dt=DecisionTreeClassifier()

# %%
#Training Testing and Spliting the data
x_train,x_test,y_train,y_test=train_test_split(x_new,y_new,test_size=0.25,random_state=47)

# %%
#Training the data
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#calling the function and passing the dataset for logistic regression
metric_score(dt,x_train,x_test,y_train,y_test,train=True)#for training
metric_score(dt,x_train,x_test,y_train,y_test,train=False)#for testing
# Out:
# =====Train Score=====
# Accuracy Score: 100.00%
#
# =====Test Score=====
# Accuracy Score: 93.48%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93     10603
#            1       0.92      0.95      0.94     10647
#
#     accuracy                           0.93     21250
#    macro avg       0.94      0.93      0.93     21250
# weighted avg       0.94      0.93      0.93     21250
#
#
#  Confusion Matrix:
#  [[ 9738   865]
#  [  521 10126]]
#
#  True Negatives (TN): 9738
#  False Positives (FP): 865
#  False Negatives (FN): 521
#  True Positives (TP): 10126
#
#  F1 Score:
#  0.9359460208891766
# Sensitivity (Recall): 94.92%
# Specificity (True Negative Rate):92.13%

# %%
y_pred=dt.predict(x_test)
test_accuracy=accuracy_score(y_test,y_pred)

# %%
#Checking cross validation score
for j in range(2,6):
    cv_score=cross_val_score(dt,x_new,y_new,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is{cv_mean}and accuracy for the testing is {test_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is0.9277411764705883and accuracy for the testing is 0.9379764705882353
#
#
# at cross fold 3 the cv score is0.9391647508476827and accuracy for the testing is 0.9379764705882353
#
#
# at cross fold 4 the cv score is0.9408470588235294and accuracy for the testing is 0.9379764705882353
#
#
# at cross fold 5 the cv score is0.9480235294117648and accuracy for the testing is 0.9379764705882353

# %%
#plotting roc curve
fpr,tpr,threshold=roc_curve(y_test,y_pred)

# %%
print('FPR',fpr)
print('TPR',tpr)
print('Threshold',threshold)
# Out:
# FPR [0.        0.0791056 1.       ]
# TPR [0.         0.95511974 1.        ]
# Threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='blue',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
#Making dataframe of all the models
data=pd.DataFrame({
    'Models':['Logistic','Random Forest','KNN','Decision Tree'],
    'Training Score':[77.31,100,94.80,100],
    'Testing Score':[77.31,96.35,92.69,93.48],
    'F1 score':[96.87,93.54,89.99,96.87],
    'Sensitivity':[78.82,98.18,98.89,94.92],
    'Specificity':[75.96,94.67,87.90,92.13],
    'Cross Val Score':[77.30,96.30,92.70,92.77]
    
})
data
# Out:
#           Models  Training Score  Testing Score  F1 score  Sensitivity  \
# 0       Logistic           77.31          77.31     96.87        78.82
# 1  Random Forest          100.00          96.35     93.54        98.18
# 2            KNN           94.80          92.69     89.99        98.89
# 3  Decision Tree          100.00          93.48     96.87        94.92
#
#    Specificity  Cross Val Score
# 0        75.96            77.30
# 1        94.67            96.30
# 2        87.90            92.70
# 3        92.13            92.77

# %%
#Using Grid Search cv for hyperparameter tuning for RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
#param_grid=({
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
})#

# %%
 #param_grid =({
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
})#

# %%
param_grid = ({
    'n_neighbors': [3, 5, 7, 9],  
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'chebyshev']
})

# %%
grid_search=GridSearchCV(knn,param_grid=param_grid,cv=4)

# %%
#Training
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan', 'chebyshev'],
#                          'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']})

# %%
#best Parameters
grid_search.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}

# %%
#Training with the best parameters
#rfc=RandomForestClassifier(max_depth=None,max_features='log2',min_samples_leaf=1,min_samples_split=2,n_estimators=150)
rfc.fit(x_train,y_train)#
# Out:
# RandomForestClassifier(max_features='log2', n_estimators=150)

# %%
#Training with the best parameters
knn=KNeighborsClassifier(metric='manhattan',n_neighbors=3,weights='distance')
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=3, weights='distance')

# %%
#calling the function and passing the dataset
#metric_score(rfc,x_train,x_test,y_train,y_test,train=True)#Training Score
metric_score(rfc,x_train,x_test,y_train,y_test,train=False)#Testing Score#
# Out:
# =====Train Score=====
# Accuracy Score:100.00%
#
# =====Test Score=====
# Accuracy Score:95.76%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96     10544
#            1       0.94      0.98      0.96     10706
#
#     accuracy                           0.96     21250
#    macro avg       0.96      0.96      0.96     21250
# weighted avg       0.96      0.96      0.96     21250
#
#
#  Confusion Matrix:
#  [[ 9881   663]
#  [  239 10467]]
#
#  F1 Score:
#  0.9586920681443488

# %%
#calling the function and passing the dataset
metric_score(knn,x_train,x_test,y_train,y_test,train=True)#Training Score
metric_score(knn,x_train,x_test,y_train,y_test,train=False)#Testing Score
# Out:
# =====Train Score=====
# Accuracy Score: 100.00%
#
# =====Test Score=====
# Accuracy Score: 94.84%
#
#  Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95     10603
#            1       0.91      0.99      0.95     10647
#
#     accuracy                           0.95     21250
#    macro avg       0.95      0.95      0.95     21250
# weighted avg       0.95      0.95      0.95     21250
#
#
#  Confusion Matrix:
#  [[ 9613   990]
#  [  106 10541]]
#
#  True Negatives (TN): 9613
#  False Positives (FP): 990
#  False Negatives (FN): 106
#  True Positives (TP): 10541
#
#  F1 Score:
#  0.9505816574984219
# Sensitivity (Recall): 98.91%
# Specificity (True Negative Rate):91.41%

# %%
#Checking cross validation score
cv_score=cross_val_score(knn,x_new,y_new,cv=4)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9489882352941176

# %%
#Checking AUC Score
roc_auc_score=roc_auc_score(y_test,y_pred)
roc_auc_score
# Out:
# 0.9267389257667771

# %%
#saving the model
#Importing required libraries
import pickle
pickle.dump(knn,open('Cerebral Stroke Prediction Project','wb'))

# %%
#Loading the saved model
model=pickle.load(open('Cerebral Stroke Prediction Project','rb'))

# %%
#Prediction
prediction=model.predict(x_test)
prediction
# Out:
# array([1, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
#This are the predicted strokes
Predicted_stroke=pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=['Predicted','Actual'])
Predicted_stroke
# Out:
#            0      1      2      3      4      5      6      7      8      \
# Predicted      1      0      0      0      1      0      0      1      0
# Actual         1      0      0      0      1      0      0      1      0
#
#            9      ...  21240  21241  21242  21243  21244  21245  21246  21247  \
# Predicted      1  ...      1      1      1      1      1      1      0      1
# Actual         1  ...      1      1      1      1      1      1      0      1
#
#            21248  21249
# Predicted      0      0
# Actual         0      0
#
# [2 rows x 21250 columns]
